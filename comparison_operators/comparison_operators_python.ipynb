# %%
# == Compares if two values are the same or not, returns boolean True or False depedning on the comparison 
2 == 2
# Out:
# True

# %%
2 == 4
# Out:
# False

# %%
# You can compare strings
'hello' == 'bye'
# Out:
# False

# %%
'hi' == 'hi'
# Out:
# True

# %%
# When comparing strings, it is cap sensitive 
'Hi' == 'hi'
# Out:
# False

# %%
'2' == 2
# Out:
# False

# %%
# != Compares if two values are not the same. If they are not the same, it is True. If they are the same,
# then False as we check if they are different

2 != 2
# Out:
# False

# %%
2 != 4
# Out:
# True

# %%
# Ints and floats are not sensitive unless value is different. Here 2.0 and 2 are both technically the same despite type being different
2.0 == 2
# Out:
# True

# %%
2.5 == 2
# Out:
# False

# %%
# Greater than > or less than < checks if a value on left is greater or less than on right. It outputs boolean True or False

#greater than: basically saying "Is 2 greater than 1?"
2 > 1
# Out:
# True

# %%
# Is 2 greater than 4?
2 > 4
# Out:
# False

# %%
# Is 1 less than 2?
1 < 2
# Out:
# True

# %%
# Is 6 less than 3?
6 < 3
# Out:
# False

# %%
# Greater than or for less than equal. Where >= or <= will include the number instead of excluding the min max number.
# If we check 1 greater than 1, it will return false as they're equal
1 > 1
# Out:
# False

# %%
# However if we want it to say true where we would be happy to output True when comparing two values of the same say 1 and 1 in our example,
# we use = after > or < like >= and <=.

1 >= 1
# Out:
# True

# %%
3<=3
# Out:
# True
