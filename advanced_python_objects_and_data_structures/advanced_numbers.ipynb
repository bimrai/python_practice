# %% [markdown]
# # Advanced Numbers

# %%
# hexadecimal representation

hex(10)
# Out:
# '0xa'

# %%
hex(5)
# Out:
# '0x5'

# %%
# binary

bin(10)
# Out:
# '0b1010'

# %%
bin(5)
# Out:
# '0b101'

# %%
# raise to the power **
5**3
# Out:
# 125

# %%
# pow for power does same thing as **
pow(5,3)
# Out:
# 125

# %%
# if you add a third value to pow it will become a mod aka modulo
pow(2, 3, 5) # output 3 2 * 2 * 2 = 8,8%5 = 3
# Out:
# 3

# %%
# abs for absolute value

abs(0)
# Out:
# 0

# %%
abs(4)
# Out:
# 4

# %%
abs(-5)
# Out:
# 5

# %%
# round just rounds it
round(3.2)
# Out:
# 3

# %%
round(3.7)
# Out:
# 4

# %%
# if you want to see just a certain decimal places point use round(value, decimalplace)

round(4.6452525, 2)
# Out:
# 4.65
