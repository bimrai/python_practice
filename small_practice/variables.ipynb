# %%
a = 5

# %%
a
# Out:
# 5

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a + a
# Out:
# 20

# %%
a = a + a

# %%
a
# Out:
# 20

# %%
type(a)
# Out:
# int

# %%
b = 1.5

# %%
type(b)
# Out:
# float

# %%
my_income = 100

tax_rate = 0.1

my_tax = my_income * tax_rate

# %%
my_tax
# Out:
# 10.0
