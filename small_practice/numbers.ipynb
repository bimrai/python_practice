# %%
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*2
# Out:
# 4

# %%
4/2
# Out:
# 2.0

# %%
7/4
# Out:
# 1.75

# %%
7 % 4
# Out:
# 3

# %%
50 % 5
# Out:
# 0

# %%
23 % 2
# Out:
# 1

# %%
20 %2
# Out:
# 0

# %%
2 ** 3 # ** double star means power so 2 to the power of 3 or 2 cube
# Out:
# 8

# %%
2 + 10 * 10 + 3 # does 10 * 10 = 100  first, then 2 + 3 = 5 , finally 100 + 5 = 105
# Out:
# 105

# %%
(2 + 10) * (10 + 3) # parenthesis scope first, so 2 + 10 = 12, 10 + 3 = 13, then 12 * 13 = 156
# Out:
# 156

# %%
0.1 + 0.2 - 0.3
# Out:
# 5.551115123125783e-17
