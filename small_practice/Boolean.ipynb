# %% [markdown]
# # Booleans
#
# True or False. That's all. They work best in conditional statements, logical statements or functions.

# %%
# First letters on True and False must be capital. If not, syntax nameError will return name 'true' is not defined.
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True) # returns boolean or bool for short
# Out:
# bool

# %%
# Same with False
type(False)
# Out:
# bool

# %%
# Using operators return bools too
2 > 1 # Checks if 2 is bigger than 1, which is true so it returns True
# Out:
# True

# %%
# Now lets check if 2 is less than 1, in other words we are checking if 1 is bigger than 2
2 < 1
# Out:
# False

# %%
# There are many logical operators to check if something is true or not

1 == 1 # == comparison operators
# Out:
# True

# %%
2 == 1
# Out:
# False

# %%
1 != 1 # inequality operator
# Out:
# False

# %%
10 != 100
# Out:
# True

# %%
# We can use the None keyword as a placeholder for an object we don't want to assign yet

b = None
b # Returning b or calling b, it wont return or output anything due to None.
