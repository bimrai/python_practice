# %%
# Tuples are within parentheses. Lists are between square brackets.

my_tuple = (1, 2, 3) # tuple

my_list = [1, 2, 3] # list

# Tuples are immutable. Once an element is inside a tuple, it cannot be reassigned.

# %%
# We can test their types here
type(my_tuple)
# Out:
# tuple

# %%
type(my_list)
# Out:
# list

# %%
# You can check length too using len() method from previous lessons on tuples
len(my_tuple)
# Out:
# 3

# %%
# You can mix tuples element or data like string or int no problems occured

mix_tuple = ('word', 1)

mix_tuple
# Out:
# ('word', 1)

# %%
# Slicing and indexing works too

mix_tuple[0]
# Out:
# 'word'

# %%
mix_tuple[-1] # reverse indexing
# Out:
# 1

# %%
# In built index and count method

t = ('a', 'a', 'b')

# We can check how many times a shows up in this tuple

t.count('a')
# Out:
# 2

# %%
t.index('a') # Index shows in which index the very first time the value you input shows up within the tuple.
# Out:
# 0

# %%
# Let's check b.
t.index('b')
# Out:
# 2

# %%
# so unlike lists again, we cannot reassign tuples. Let's see the difference between tuples and lists. 

# List
the_list = [1, 2, 3, 4]
the_list[0] = 'One'
the_list
# Out:
# ['One', 2, 3, 4]

# %%
# Now tuples mutatability. Remember it will NOT mutate, hence immutable.

the_tuple = ('One', 'Two', 'Three')
the_tuple[1] = 2
the_tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       1 # Now tuples mutatability. Remember it will NOT mutate, hence immutable.
#       3 the_tuple = ('One', 'Two', 'Three')
# ----> 4 the_tuple[1] = 2
#       5 the_tuple
#
# TypeError: 'tuple' object does not support item assignment

# %%
# The error was to be expected!
