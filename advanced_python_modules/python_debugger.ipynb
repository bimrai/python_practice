# %% [markdown]
# # Debugging

# %%
x = [1, 2, 3]
y = 2
z = 3

result = y + z
result2 = x + y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 z = 3
#       5 result = y + z
# ----> 6 result2 = x + y
#
# TypeError: can only concatenate list (not "int") to list

# %%
# you can also print to see the errors targetting specific problems 

x = [1, 2, 3]
y = 2
z = 3

result = y + z
print(result)
result2 = x + y
print(result2)
# Out:
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       7 result = y + z
#       8 print(result)
# ----> 9 result2 = x + y
#      10 print(result2)
#
# TypeError: can only concatenate list (not "int") to list

# %%
# you can use python debugger to set a trace

# set trace before error line, so before your code you want to test/debug

import pdb

# %%
x = [1, 2, 3]
y = 2
z = 3

result_one = y + z

pdb.set_trace()
result_two = y + x
# Out:
# > c:\users\birah\appdata\local\temp\ipykernel_31308\2880022366.py(7)<module>()
# ipdb>  x
# [1, 2, 3]
# ipdb>  y
# 2
# ipdb>  z
# 3
# ipdb>  result_one
# 5
# ipdb>  result_two
# *** NameError: name 'result_two' is not defined
# ipdb>  q

# %%
# python debugger opens a search like bar and you can search, call/test, and q to quit once done
