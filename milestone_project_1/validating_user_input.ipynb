# %%
def user_choice():

    choice = input("Enter Number 0 - 10: ")

    return int(choice)

# %%
user_choice()
# Out:
# Enter Number 0 - 10:  1
# 1

# %%
user_choice()
# Out:
# Enter Number 0 - 10:  one
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 user_choice()
#
# Cell In[1], line 5, in user_choice()
#       1 def user_choice():
#       3     choice = input("Enter Number 0 - 10: ")
# ----> 5     return int(choice)
#
# ValueError: invalid literal for int() with base 10: 'one'

# %%
# We can check type int like so

some_value = '1'

# %%
some_value.isdigit()
# Out:
# True

# %%
# true so we can pass into int

int(some_value)
# Out:
# 1

# %%
def user_choice():

    choice = 'WRONG'

    while choice.isdigit() == False:
        choice = input("Enter Number 0 - 10: ")

        if choice.isdigit() == False:
            print('Please enter number!')

    return int(choice)

# %%
user_choice()
# Out:
# Enter Number 0 - 10:  2d
# Please enter number!
# Enter Number 0 - 10:  fw
# Please enter number!
# Enter Number 0 - 10:  2440
# 2440

# %%
result = 'WRONG VALUE'

# %%
acceptable_values = [1, 2, 3]

# %%
result in acceptable_values
# Out:
# False

# %%
result not in acceptable_values
# Out:
# True

# %%
def user_input():

    # vars

    # initial choice
    choice = 'WRONG'
    acceptable_range = range(0, 10)
    within_range = False

    # check two conditions

    # check digit or check within range == false
    while choice.isdigit() == False or within_range == False:
        choice = input("Enter Number 0 - 10: ")

        # digit checker
        if choice.isdigit() == False:
            print('Please Enter Number.')

        # range check
        if choice.isdigit() == True:
            if int(choice) in acceptable_range:
                within_range = True
                print(f'You Entered: {choice}')
            else:
                print('Please Enter Number from, 1 - 10.')
                within_range = False
            

    return int(choice)

# %%
user_input()
# Out:
# Enter Number 0 - 10:  800
# Please Enter Number from, 1 - 10.
# Enter Number 0 - 10:  Four
# Please Enter Number.
# Enter Number 0 - 10:  7
# You Entered: 7
# 7
