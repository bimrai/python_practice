# %%
game_list = [0, 1, 2]

# %%
def display_game(game_list):
    print("Here is the current list")
    print(game_list)

# %%
display_game(game_list)
# Out:
# Here is the current list
# [0, 1, 2]

# %%
def position_choice():

    choice = "Wrong"

    while choice not in ['0', '1', '2']:
        
        choice = input("Choose position 0, 1 or 2: ")

        if choice not in ['0', '1', '2']:
            print("Invalid position!")

    return int(choice)

# %%
position_choice()
# Out:
# Choose position 0, 1 or 2:  1
# 1

# %%
def replacement_choice(game_list, position):

    user_choice = input("Type a X or O on your chosen position.")

    game_list[position] = user_choice

    return game_list

# %%
replacement_choice(game_list,1)
# Out:
# Type a X or O on your chosen position. X
# [0, 'X', 2]

# %%
def gameon_choice():

    choice = "Wrong"

    while choice not in ['Y', 'N']:
        
        choice = input("Keep playing? Type Y or N: ")

        if choice not in ['Y', 'N']:
            print("Please type Y or N")

        if choice == 'N':
            print("You have exited the game.")

    if choice == 'Y':
        return True
    else:
        return False

# %%
gameon_choice()
# Out:
# Keep playing? Type Y or N:  Y
# True

# %%
game_on = True
game_list = [0, 1, 2]

while game_on:
    
    display_game(game_list)

    position = position_choice()

    game_list = replacement_choice(game_list, position)

    display_game(game_list)

    game_on = gameon_choice()
# Out:
# Here is the current list
# [0, 1, 2]
# Choose position 0, 1 or 2:  1
# Type a X or O on your chosen position. X
# Here is the current list
# [0, 'X', 2]
# Keep playing? Type Y or N:  N
# You have exited the game.
