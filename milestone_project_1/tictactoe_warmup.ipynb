# %% [markdown]
# # Displaying Info
#
# So we can dsplay info in the terminal via print. Our project is a tic tac toe game, so we will need a grid like UI. We can do this by stacking print on top of each other.

# %%
print([1, 2, 3])
print([4, 5, 6])
print([7, 8, 9])
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]

# %% [markdown]
# However we don't want this like that. We want it more modular. We can do this in a function.

# %%
def display(row1, row2, row3):
    print(row1)
    print(row2)
    print(row3)

# %%
example_row = [1, 2, 3]

display(example_row, example_row, example_row)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]

# %%
# We can also do this

row1 = [' ', ' ', ' ']
row2 = [' ', ' ', ' ']
row3 = [' ', ' ', ' ']

# %%
display(row1, row2, row3)
# Out:
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# [' ', ' ', ' ']

# %%
row2[1] = 'X'

# %%
display(row1, row2, row3)
# Out:
# [' ', ' ', ' ']
# [' ', 'X', ' ']
# [' ', ' ', ' ']

# %% [markdown]
# # Accepting User Input

# %%
input("Please enter a value: ")
# Out:
# Please enter a value:  5
# '5'

# %%
# store the user input value

result = input("Please enter a value: ")
# Out:
# Please enter a value:  I am stored in result

# %%
result
# Out:
# 'I am stored in result'

# %%
# Remember anything passed in input is a string, even if a number is passed through

value = input("Please enter a value: ")
# Out:
# Please enter a value:  5

# %%
type(value) # we know value stores 5 as we input 5 above. It will still showcase as str type
# Out:
# str

# %%
# We must convert it into a int or floating point

result = input("Please enter a value: ")
# Out:
# Please enter a value:  50

# %%
result
# Out:
# '50'

# %%
result_int = int(result)

# %%
type(result) # original
# Out:
# str

# %%
# the var that stores he "int(result)" where result is converted to int via int()

type(result_int)
# Out:
# int

# %%
# You can also convert a string to float

pie = float('3.14')
pie
# Out:
# 3.14

# %%
type(pie)
# Out:
# float

# %%
position_index = input("Choose an index position: ")
# Out:
# Choose an index position:  1

# %%
# doesnt work because 1 is a str not an int
row1[position_index]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 # doesnt work because 1 is a str not an int
# ----> 2 row1[position_index]
#
# TypeError: list indices must be integers or slices, not str

# %%
# you wrap int around the "input("Choose an index position: ")"
# not only does this make it a str to int, it type checks so no other inputs can be used or will be accepted

position_index = int(input("Choose an index position: "))
# Out:
# Choose an index position:  2

# %%
type(position_index)
# Out:
# int

# %%
# now we can use it in the row. This will be in the middle as its between row1 and 2, within the 3 columns where 1 is the second box in list

row2[position_index]
# Out:
# 'X'

# %%
display(row1, row2, row3)
# Out:
# [' ', ' ', ' ']
# [' ', 'X', ' ']
# [' ', ' ', ' ']
