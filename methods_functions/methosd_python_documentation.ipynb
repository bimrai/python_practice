# %% [markdown]
# # Methods and Python Documentation

# %%
# We've already seen some useful methods

# append adds on end
mylist = [1, 2, 3, 4, 5]
mylist.append(6) 
mylist
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# pops end of lists item
mylist.pop()
# Out:
# 6

# %%
mylist # check after pop
# Out:
# [1, 2, 3, 4, 5]

# %%
# Quick ways to get the list of methods for various built in python objects. 
# First just write a variable name, then a dot, '.' and after that just press tab. You can scroll and see whats available
# mylist. <- like so and tab after


# We can see a .instert() method
# If we don't know what it can do, press shift + tab to get more details: Below is what we get for the insert info

# Signature: mylist.insert(index, object, /)
# Docstring: Insert object before index.
# Type:      builtin_function_or_method

# If not on jupyter notebook, use the built in help function. Just like so: help(mylist.insert), it will return the same info as above.
# OR Python documentation.


# inserts numbers upon index place then the value or object (for this context)
mylist.insert(5, 6) 
mylist
# Out:
# [1, 2, 3, 4, 5, 6]
