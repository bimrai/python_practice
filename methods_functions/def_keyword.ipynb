# %% [markdown]
# # def Keyword
#
# def is the keyword when creating functions. After def, name your function via snake casing.
#
# def name _of_function():
#
#     '''
#
#     Docstring explains function.  <- Docstring multi-line string is to describe a function, it will not print out or run in code.
#
#     '''
#
#     print("hello") <- prints hello
#
# \>> name _of_function() <function is called/can be executed and we can see results
#
# \>> Hello

# %%
# example

def name_of_function():
    '''
    docstring
    '''
    print('Hello')

name_of_function()
# Out:
# Hello

# %%
# Can become more complexed. Functions can accept aruments to be passed by the user. Let's use name as a made up variable to pass in as argu

def name_of_function(name): # call var argument wahtever you want. For now we call it name where user inputs name
    '''
    docstring
    '''
    print('Hello' + ' ' + name + '!') # or just do print('Hello', name) 

name_of_function("Bim")
# Out:
# Hello Bim!

# %%
# We typically use return as it allows us to assign the output of a function to a new variable

def add_functinon(num1, num2): # arguments/parameters are variables you can use within function and run code or return like so
    return num1 + num2 # print doesnt let us do this. We can only do it if we assign num1 = 4, num2 = 6 and then reassign these results into
                       # another variable were total = num1 + num2 and then print(total).

    #So key, most functions will use return. Rarely will a functino only print.

add_functinon(4, 6) # call and make sure to add
# Out:
# 10
